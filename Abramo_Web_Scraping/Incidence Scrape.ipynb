# %% [markdown]
# ## Dependencies

# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver
import pandas as pd

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/101.0.4951.41/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\drewa\.wdm\drivers\chromedriver\win32\101.0.4951.41]

# %% [markdown]
# ## Cancer Incidence Data

# %%
# Visit the State Cancer Profile(Incidence) site
url = 'https://www.statecancerprofiles.cancer.gov/incidencerates/index.php?stateFIPS=06&areatype=county&cancer=076&race=00&sex=0&age=001&stage=999&year=0&type=incd&sortVariableName=rate&sortOrder=default&output=0#results'
browser.visit(url)
# Optional delay for loading the page
browser.is_element_present_by_css('div.col-xs-9', wait_time=1)
# Out:
# True

# %%
# Set the html parameter of interest
html = browser.html
can_soup = soup(html, 'html.parser')
slide_elem = can_soup.select_one('fieldset')

# %%
print(slide_elem.prettify())
# Out:
# <fieldset>
#  <legend>
#   Data Options
#  </legend>
#  <div class="inputWrap cf">
#   <label for="stateFIPS">
#    <strong>
#     Area:
#    </strong>
#   </label>
#   <select id="stateFIPS" name="stateFIPS" onchange="updateAreaType();">
#    <option value="*">
#     --- choose state ---
#    </option>
#    <option value="00">
#     United States
#    </option>
#    <option value="01">
#     Alabama
#    </option>
#    <option value="02">
#     Alaska
#    </option>
#    <option value="04">
#     Arizona
#    </option>
#    <option value="05">
#     Arkansas
#    </option>
#    <option selected="selected" value="06">
#     California
#    </option>
#    <option value="08">
#     Colorado
#    </option>
#    <option value="09">
#     Connecticut
#    </option>
#    <option value="10">
#     Delaware
#    </option>
#    <option value="11">
#     District of Columbia
#    </option>
#    <option value="12">
#     Florida
#    </option>
#    <option value="13">
#     Georgia
#    </option>
#    <option value="15">
#     Hawaii
#    </option>
#    <option value="16">
#     Idaho
#    </option>
#    <option value="17">
#     Illinois
#    </option>
#    <option value="18">
#     Indiana
#    </option>
#    <option value="19">
#     Iowa
#    </option>
#    <option value="20">
#     Kansas
#    </option>
#    <option value="21">
#     Kentucky
#    </option>
#    <option value="22">
#     Louisiana
#    </option>
#    <option value="23">
#     Maine
#    </option>
#    <option value="24">
#     Maryland
#    </option>
#    <option value="25">
#     Massachusetts
#    </option>
#    <option value="26">
#     Michigan
#    </option>
#    <option value="27">
#     Minnesota
#    </option>
#    <option value="28">
#     Mississippi
#    </option>
#    <option value="29">
#     Missouri
#    </option>
#    <option value="30">
#     Montana
#    </option>
#    <option value="31">
#     Nebraska
#    </option>
#    <option value="32">
#     Nevada
#    </option>
#    <option value="33">
#     New Hampshire
#    </option>
#    <option value="34">
#     New Jersey
#    </option>
#    <option value="35">
#     New Mexico
#    </option>
#    <option value="36">
#     New York
#    </option>
#    <option value="37">
#     North Carolina
#    </option>
#    <option value="38">
#     North Dakota
#    </option>
#    <option value="39">
#     Ohio
#    </option>
#    <option value="40">
#     Oklahoma
#    </option>
#    <option value="41">
#     Oregon
#    </option>
#    <option value="42">
#     Pennsylvania
#    </option>
#    <option value="72">
#     Puerto Rico
#    </option>
#    <option value="44">
#     Rhode Island
#    </option>
#    <option value="45">
#     South Carolina
#    </option>
#    <option value="46">
#     South Dakota
#    </option>
#    <option value="47">
#     Tennessee
#    </option>
#    <option value="48">
#     Texas
#    </option>
#    <option value="49">
#     Utah
#    </option>
#    <option value="50">
#     Vermont
#    </option>
#    <option value="51">
#     Virginia
#    </option>
#    <option value="53">
#     Washington
#    </option>
#    <option value="54">
#     West Virginia
#    </option>
#    <option value="55">
#     Wisconsin
#    </option>
#    <option value="56">
#     Wyoming
#    </option>
#   </select>
#  </div>
#  <div class="inputWrap cf" style="display: block;">
#   <label for="areatype">
#    <strong>
#     Area Type:
#    </strong>
#   </label>
#   <select id="areatype" name="areatype" onchange="updateYear();" style="display: block;">
#    <option value="*">
#     --- choose area type ---
#    </option>
#    <option value="county">
#     By County
#    </option>
#    <option value="hsa">
#     By Health Service Area (HSA)
#    </option>
#   </select>
#  </div>
#  <div class="inputWrap cf">
#   <label for="cancer">
#    <strong>
#     Cancer:
#    </strong>
#   </label>
#   <select id="cancer" name="cancer" onchange="updateAges();updateSexes();updateStages();">
#    <option value="*">
#     --- choose cancer ---
#    </option>
#    <option value="001">
#     All Cancer Sites
#    </option>
#    <option value="071">
#     Bladder
#    </option>
#    <option selected="selected" value="076">
#     Brain &amp; ONS
#    </option>
#    <option value="055">
#     Breast (Female)
#    </option>
#    <option value="400">
#     Breast (Female in situ)
#    </option>
#    <option value="057">
#     Cervix
#    </option>
#    <option value="516">
#     Childhood (Ages &lt;15, All Sites)
#    </option>
#    <option value="515">
#     Childhood (Ages &lt;20, All Sites)
#    </option>
#    <option value="020">
#     Colon &amp; Rectum
#    </option>
#    <option value="017">
#     Esophagus
#    </option>
#    <option value="072">
#     Kidney &amp; Renal Pelvis
#    </option>
#    <option value="090">
#     Leukemia
#    </option>
#    <option value="035">
#     Liver &amp; Bile Duct
#    </option>
#    <option value="047">
#     Lung &amp; Bronchus
#    </option>
#    <option value="053">
#     Melanoma of the Skin
#    </option>
#    <option value="086">
#     Non-Hodgkin Lymphoma
#    </option>
#    <option value="003">
#     Oral Cavity &amp; Pharynx
#    </option>
#    <option value="061">
#     Ovary
#    </option>
#    <option value="040">
#     Pancreas
#    </option>
#    <option value="066">
#     Prostate
#    </option>
#    <option value="018">
#     Stomach
#    </option>
#    <option value="080">
#     Thyroid
#    </option>
#    <option value="058">
#     Uterus (Corpus &amp; Uterus, NOS)
#    </option>
#   </select>
#  </div>
#  <div class="inputWrap cf">
#   <label for="race">
#    <strong>
#     Race/Ethnicity:
#    </strong>
#   </label>
#   <select id="race" name="race">
#    <option value="*">
#     --- choose race/ethnicity ---
#    </option>
#    <option selected="selected" value="00">
#     All Races (includes Hispanic)
#    </option>
#    <option value="01">
#     White (includes Hispanic)
#    </option>
#    <option value="06">
#     White Hispanic
#    </option>
#    <option value="07">
#     White Non-Hispanic
#    </option>
#    <option value="02">
#     Black (includes Hispanic)
#    </option>
#    <option value="03">
#     Amer. Indian / AK Native (includes Hispanic)
#    </option>
#    <option value="04">
#     Asian / Pacific Islander (includes Hispanic)
#    </option>
#    <option value="05">
#     Hispanic (any race)
#    </option>
#   </select>
#  </div>
#  <div class="inputWrap cf" style="display: block;">
#   <label for="sex">
#    <strong>
#     Sex:
#    </strong>
#   </label>
#   <select id="sex" name="sex" style="display: block;">
#    <option value="*">
#     --- choose sex ---
#    </option>
#    <option value="0">
#     Both Sexes
#    </option>
#    <option value="1">
#     Males
#    </option>
#    <option value="2">
#     Females
#    </option>
#   </select>
#  </div>
#  <div class="inputWrap cf" style="display: block;">
#   <label for="age">
#    <strong>
#     Age:
#    </strong>
#   </label>
#   <select id="age" name="age" style="display: block;">
#    <option value="*">
#     --- choose age group ---
#    </option>
#    <option value="001">
#     All Ages
#    </option>
#    <option value="009">
#     &lt;50
#    </option>
#    <option value="136">
#     50+
#    </option>
#    <option value="006">
#     &lt;65
#    </option>
#    <option value="157">
#     65+
#    </option>
#   </select>
#  </div>
#  <div class="inputWrap cf" style="display: block;">
#   <label for="stage">
#    <strong>
#     Stage:
#    </strong>
#   </label>
#   <select id="stage" name="stage" style="display: block;">
#    <option value="999">
#     All Stages
#    </option>
#    <option value="211">
#     Late Stage (Regional &amp; Distant)
#    </option>
#   </select>
#  </div>
#  <div class="inputWrap cf" style="display: block;">
#   <label for="year">
#    <strong>
#     Year:
#    </strong>
#   </label>
#   <select id="year" name="year" style="display: block;">
#    <option value="0">
#     Latest 5-Year Average
#    </option>
#   </select>
#  </div>
#  <input name="type" type="hidden" value="incd"/>
#  <input name="sortVariableName" type="hidden" value="rate"/>
#  <input name="sortOrder" type="hidden" value="default"/>
#  <input name="output" type="hidden" value="0"/>
# </fieldset>

# %%
slide_elem.find_all('option')[59:81]
# Out:
# [<option value="071">Bladder</option>,
#  <option selected="selected" value="076">Brain &amp; ONS</option>,
#  <option value="055">Breast (Female)</option>,
#  <option value="400">Breast (Female in situ)</option>,
#  <option value="057">Cervix</option>,
#  <option value="516">Childhood (Ages &lt;15, All Sites)</option>,
#  <option value="515">Childhood (Ages &lt;20, All Sites)</option>,
#  <option value="020">Colon &amp; Rectum</option>,
#  <option value="017">Esophagus</option>,
#  <option value="072">Kidney &amp; Renal Pelvis</option>,
#  <option value="090">Leukemia</option>,
#  <option value="035">Liver &amp; Bile Duct</option>,
#  <option value="047">Lung &amp; Bronchus</option>,
#  <option value="053">Melanoma of the Skin</option>,
#  <option value="086">Non-Hodgkin Lymphoma</option>,
#  <option value="003">Oral Cavity &amp; Pharynx</option>,
#  <option value="061">Ovary</option>,
#  <option value="040">Pancreas</option>,
#  <option value="066">Prostate</option>,
#  <option value="018">Stomach</option>,
#  <option value="080">Thyroid</option>,
#  <option value="058">Uterus (Corpus &amp; Uterus, NOS)</option>]

# %%
age = []
results = slide_elem.find_all('option')[96:100]
for result in results:
    x = result.attrs['value']
    age.append(x)
age
# Out:
# ['009', '136', '006', '157']

# %%
# Loop through State options
state = []
for x in slide_elem.find_all('option')[2:54]:
    state.append(x)

# %%
# Cancer Incidence Data(2015-2019)

# Data options lists
#Area
state = []
results = slide_elem.find_all('option')[2:54]
for result in results:
    x = result.attrs['value']
    state.append(x)
# Cancer
cancer = []
results = slide_elem.find_all('option')[59:81]
for result in results:
    x = result.attrs['value']
    cancer.append(x)
# Race/Ethnicity
race = []
results = slide_elem.find_all('option')[83:90]
for result in results:
    x = result.attrs['value']
    race.append(x)
# Sex
sex = []
results = slide_elem.find_all('option')[92:94]
for result in results:
    x = result.attrs['value']
    sex.append(x)
# Age
age = []
results = slide_elem.find_all('option')[96:100]
for result in results:
    x = result.attrs['value']
    age.append(x)

site = f'https://www.statecancerprofiles.cancer.gov/incidencerates/index.php?stateFIPS={state}&areatype=county&cancer={cancer}&race={race}}&sex={sex}&age={age}&stage=999&year=0&type=incd&sortVariableName=rate&sortOrder=default&output=0#results'
# For loop to change all data options to relevant data points

# Select specific features
For x in Area:
    #Select in Area
    For x in Cancer:
        # Select in Cancer
        # Reset all other fields
        df = pd.read_html(site)[0]
        df.append(pd.read_html(site)[0])
    For x in Race/Ethnicity:
        # Select Race/Ethnicity
        # Reset all other fields
        df.append(pd.read_html(site)[0])
    For x in Sex:
        # Select Sex
        # Reset all other fields
        # Generate table .click()
        df.append(pd.read_html(site)[0])
    For x in Age:
        # Select Age
        # Reset all other fields
        # Generate table .click()
        df.append(pd.read_html(site)[0])
    For x in Stage:
        # Select Stage
        # Reset all other fields
        # Generate table .click()
        df.append(pd.read_html(site)[0])
Dataframe.head()

# %%
# Save DataFrame as csv

# %% [markdown]
# ## Cancer Mortality Data

# %%
# Visit the State Cancer Profile(Mortality) site
url = 'https://www.statecancerprofiles.cancer.gov/deathrates/index.php'
browser.visit(url)
# Optional delay for loading the page
browser.is_element_present_by_css('div.col-xs-9', wait_time=1)

# %%
# Set the html parameter of interest
html = browser.html
news_soup = soup(html, 'html.parser')
slide_elem = news_soup.select_one('fieldset')

# %%
# Cancer Mortality Data(2015-2019)

# Data options lists

#Area

# Cancer

# Race/Ethnicity

# Sex

# Age

# Stage
#Set Area Type(Should be By County)
# For loop to change all data options to relevant data points

For x in Data Options:
    # Select specific features
    For x in Area:
        #Select in Area
        For x in Cancer:
            # Select in Cancer
            # Reset all other fields
            # Generate table .click()
            # Collect data from table into dataframe
        For x in Race/Ethnicity:
            # Select Race/Ethnicity
            # Reset all other fields
            # Generate table .click()
            # Collect data from table into dataframe
        For x in Sex:
            # Select Sex
            # Reset all other fields
            # Generate table .click()
            # Collect data from table into dataframe
        For x in Age:
            # Select Age
            # Reset all other fields
            # Generate table .click()
            # Collect data from table into dataframe
        For x in Stage:
            # Select Stage
            # Reset all other fields
            # Generate table .click()
            # Collect data from table into dataframe
Dataframe.head()

# %%
# Save DataFrame as csv
Cancer

# %% [markdown]
# ## Medically Underserved Areas

# %%
# Visit the HRSA data website site
url = 'https://data.hrsa.gov/tools/shortage-area/mua-find'
browser.visit(url)
# Optional delay for loading the page
browser.is_element_present_by_css('div.tab-content', wait_time=1)
# Out:
# True

# %%
# Set the html parameter of interest
html = browser.html
# Control parameters
control_soup = soup(html, 'html.parser')
control_elem = control_soup.select_one('div.tab-content')
# Collect parameter
collect_soup =soup(html, 'html.parser')
collect_elem = collect_soup.select_one('div.dataTables_scroll')

# %%
# Medically Underserved Area

# Set <input placeholder="From MM/DD/YYYY" to "1/1/2015"

# Set <input placeholder="To MM/DD/YYYY" to "12/31/2019"

# Create a list of relevant states
states = []
table = []
# Loop through states using control_elem
For x in states:
    #Change state in control_elem
    #Apply submit button <button class='btn btn-primary' type='submit'> .click()
    # Use collect_elem to select columns and data
    #MUA/P ID, Service Area Name, Designation Type, Primary State Name, County, Index of Medical Underservice Score, Rural Status
    For x in table:
        # Collect text for header columns into DataFrame
        # Collect text for all columns in the same positions into DataFrame

# %%
# Save DataFrame to CSV
