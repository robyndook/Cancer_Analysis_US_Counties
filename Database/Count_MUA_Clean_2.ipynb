# %%
import pandas as pd
mort_incd = pd.read_csv('../Resources/mort_incd.csv')
mua = pd.read_csv('../Resources/MUA_index_cook.csv')
state_abbrv = pd.read_csv('../Resources/state_abbreviation_cook.csv')
pop = pd.read_csv('../Resources/census_population_2015_2019.csv')
income = pd.read_csv('../Resources/median_income_15_19_cook.csv')

# %%
mort_incd.head()
# Out:
#   Age-Adjusted Death Rate Age-Adjusted Incidence Rate          County  \
# 0                   441.1                      1136.4    Union County
# 1                   315.8                          *   Kingman County
# 2                     283                       499.9  Buffalo County
# 3                   281.8                       558.8   Hanson County
# 4                   273.3                       596.3    Perry County
#
#   Primary_State_Name
# 0            Florida
# 1             Kansas
# 2       South Dakota
# 3       South Dakota
# 4           Kentucky

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14548/3619824122.py in <module>
# ----> 1 mort_incd.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
state_abbrv.head()
# Out:
#   Primary_State_Name Abbrv
# 0            Alabama    AL
# 1             Alaska    AK
# 2            Arizona    AZ
# 3           Arkansas    AR
# 4         California    CA

# %%
df = pd.merge(mort_incd, state_abbrv)
df.head()
# Out:
# Empty DataFrame
# Columns: [Age-Adjusted Death Rate, Age-Adjusted Incidence Rate, County, Primary_State_Name, Abbrv]
# Index: []

# %%
mua.head()
# Out:
#   Primary_State_Name        County_State  Index_of_Medical_Underservice_Score
# 0            Alabama  Autauga County, AL                                 52.0
# 1            Alabama     Bibb County, AL                                 47.0
# 2            Alabama   Blount County, AL                                 56.0
# 3            Alabama  Bullock County, AL                                 61.0
# 4            Alabama  Calhoun County, AL                                 61.0

# %%
pop.head()
# Out:
#    Unnamed: 0   STNAME         CTYNAME  POPESTIMATE2015  POPESTIMATE2016  \
# 0           0  Alabama         Alabama          4852347          4863525
# 1           1  Alabama  Autauga County            54864            55243
# 2           2  Alabama  Baldwin County           202939           207601
# 3           3  Alabama  Barbour County            26283            25806
# 4           4  Alabama     Bibb County            22566            22586
#
#    POPESTIMATE2017  POPESTIMATE2018  POPESTIMATE2019
# 0          4874486          4887681          4903185
# 1            55390            55533            55869
# 2           212521           217855           223234
# 3            25157            24872            24686
# 4            22550            22367            22394

# %%
pop.drop([ 'Unnamed: 0'], 1, inplace=True)
pop.head()
# Out:
# C:\Users\cookr\AppData\Local\Temp/ipykernel_14548/731304291.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   pop.drop([ 'Unnamed: 0'], 1, inplace=True)
#     STNAME         CTYNAME  POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  \
# 0  Alabama         Alabama          4852347          4863525          4874486
# 1  Alabama  Autauga County            54864            55243            55390
# 2  Alabama  Baldwin County           202939           207601           212521
# 3  Alabama  Barbour County            26283            25806            25157
# 4  Alabama     Bibb County            22566            22586            22550
#
#    POPESTIMATE2018  POPESTIMATE2019
# 0          4887681          4903185
# 1            55533            55869
# 2           217855           223234
# 3            24872            24686
# 4            22367            22394

# %%
income.head()
# Out:
#          County_State Abbrv  Median Household Income 2015  \
# 0  Autauga County, AL    AL                         56580
# 1  Baldwin County, AL    AL                         52387
# 2  Barbour County, AL    AL                         31433
# 3     Bibb County, AL    AL                         40767
# 4   Blount County, AL    AL                         50487
#
#    Median Household Income 2016  Median Household Income 2017  \
# 0                         54487                         58343
# 1                         56460                         56607
# 2                         32884                         32490
# 3                         43079                         45795
# 4                         47213                         48253
#
#    Median Household Income 2018  Median Household Income 2019
# 0                         59338                         58233
# 1                         57588                         59871
# ...
